# %%
import aliquot_util
ennum = aliquot_util.ennum_sn(10**5)

# %%
aliquot_util.plot_aliquot_family(100, ennum)
# Out:
# [100, 117, 65, 19, 1, 0]
# preimages 339 = [621, 2317, 9517, 16897, 18157, 23377, 24961, 26797, 27661, 28417]
# preimages 621 = [1851, 4291, 7891, 11419, 24811, 39931, 42739, 50731, 72691, 74491, 79459, 83779, 86299, 88531, 91339, 94579, 95371, 96091]
# preimages 1851 = [5541, 34789]
# preimages 5541 = [9195, 71851]
# preimages 9195 = [15285, 23253, 64309]
# preimages 23253 = [44331, 60987, 63339]
# preimages 44331 = [76629, 91989]
# preimages 4291 = [18109, 29981, 72641, 81149]
# preimages 18109 = [58355, 77987]
# preimages 29981 = [99475]
# preimages 7891 = [55181, 65549, 86669]
# preimages 11419 = [18981, 31557, 79877]
# preimages 31557 = [69459]
# preimages 2317 = [11555, 14003, 16163, 43643, 52739, 66323, 97739]
# preimages 11555 = [34653, 57745]
# preimages 14003 = [41997, 69985]
# preimages 41997 = [82179, 94299]
# preimages 9517 = [47555, 94163]
# preimages 16897 = [80645]
# preimages 18157 = [8100, 73283]
# preimages 23377 = [61295]
# preimages 28417 = [88319]
# ...
